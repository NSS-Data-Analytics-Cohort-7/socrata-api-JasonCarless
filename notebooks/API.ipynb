# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd

# %%
endpoint = 'https://data.nashville.gov/resource/fuaa-r5cm.json'

response = requests.get(endpoint)

# %%
params = {
    'year' : '2016',
    'query_text' :'fire'
}

# %%
response = requests.get(endpoint, params = params)

# %%
response
# Out:
# <Response [200]>

# %%
res = response.json()
res
# Out:
# [{'month_name': 'January',
#   'year': '2016',
#   'query_count': '19',
#   'query_text': 'fire'},
#  {'month_name': 'February',
#   'year': '2016',
#   'query_count': '35',
#   'query_text': 'fire'},
#  {'month_name': 'March',
#   'year': '2016',
#   'query_count': '32',
#   'query_text': 'fire'},
#  {'month_name': 'April',
#   'year': '2016',
#   'query_count': '26',
#   'query_text': 'fire'},
#  {'month_name': 'May',
#   'year': '2016',
#   'query_count': '24',
#   'query_text': 'fire'},
#  {'month_name': 'June',
#   'year': '2016',
#   'query_count': '31',
#   'query_text': 'fire'},
#  {'month_name': 'July',
#   'year': '2016',
#   'query_count': '24',
#   'query_text': 'fire'},
#  {'month_name': 'August',
#   'year': '2016',
#   'query_count': '47',
#   'query_text': 'fire'},
#  {'month_name': 'September',
#   'year': '2016',
#   'query_count': '36',
#   'query_text': 'fire'},
#  {'month_name': 'October',
#   'year': '2016',
#   'query_count': '38',
#   'query_text': 'fire'},
# ...

# %%
soc_dict = response.json()
socrata = pd.DataFrame.from_dict(soc_dict)

# %%
socrata
# Out:
#    month_name  year query_count query_text
# 0     January  2016          19       fire
# 1    February  2016          35       fire
# 2       March  2016          32       fire
# 3       April  2016          26       fire
# 4         May  2016          24       fire
# 5        June  2016          31       fire
# 6        July  2016          24       fire
# 7      August  2016          47       fire
# 8   September  2016          36       fire
# 9     October  2016          38       fire
# 10   November  2016          32       fire
# 11   December  2016          38       fire

# %% [markdown]
# #### It was searched the most in August

# %%
params2 = {
    'min query_count':'100'
}

# %%
response2 = requests.get(endpoint, params = params2)

# %%
response2
# Out:
# <Response [400]>

# %%
soc_dict2 = response2.json()
socrata2 = pd.DataFrame.from_dict(soc_dict2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [74], in <cell line: 2>()
#       1 soc_dict2 = response2.json()
# ----> 2 socrata2 = pd.DataFrame.from_dict(soc_dict2)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:1677, in DataFrame.from_dict(cls, data, orient, dtype, columns)
#    1674     raise ValueError("only recognize index or columns for orient")
#    1676 if orient != "tight":
# -> 1677     return cls(data, index=index, columns=columns, dtype=dtype)
#    1678 else:
#    1679     realdata = data["data"]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
# ...

# %%
socrata2
# Out:
#    month_name  year query_count           query_text month
# 0     October  2014         100                 maps   NaN
# 1       April  2015         100           employment   NaN
# 2       April  2015         100            Nashville   NaN
# 3     October  2016         100        property maps   NaN
# 4        June  2017         100      building permit   NaN
# 5        June  2017         100             assessor   NaN
# 6        July  2017         100        police report   NaN
# 7      August  2017         100         property tax   NaN
# 8      August  2017         100       property taxes   NaN
# 9      August  2017         100      building permit   NaN
# 10   November  2017         100  civil service rules   NaN
# 11   December  2017         100             holidays   NaN
# 12      April  2018         100      building permit   NaN
# 13      April  2018         100                  ess   NaN
# 14       July  2018         100                 dcso   NaN
# ...
